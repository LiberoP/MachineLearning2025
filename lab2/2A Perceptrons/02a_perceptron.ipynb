# %% [markdown]
# # Machine Learning LAB 2A: Perceptrons
#
# Course 2025/26: *F. Chiariotti*
#
# The notebook contains a simple learning task over which we will implement **MODEL SELECTION AND VALIDATION**.
#
# Complete all the **required code sections** and **answer all the questions**.
#
# ### IMPORTANT for the exam:
#
# The functions you might be required to implement in the exam will have the same signature and parameters as the ones in the labs

# %% [markdown]
# ## Classification of Stayed/Churned Customers

# %% [markdown]
# The Customer Churn table contains information on all 3,758 customers from a Telecommunications company in California in Q2 2022. Companies are naturally interested in churn, i.e., in which users are likely to switch to another company soon to get a better deal, and which are more loyal customers.
#
# The dataset contains three features:
# - **Tenure in Months**: Number of months the customer has stayed with the company
# - **Monthly Charge**: The amount charged to the customer monthly
# - **Age**: Customer's age
#
# The aim of the task is to predict if a customer will churn or not based on the three features.

# %% [markdown]
# ---

# %% [markdown]
# ## Import all the necessary Python libraries and load the dataset

# %% [markdown]
# ### The Dataset
# The dataset is a `.csv` file containing three input features and a label. Here is an example of the first 4 rows of the dataset:
#
# <center>
#
# Tenure in Months | Monthly Charge | Age | Customer Status |
# | -----------------| ---------------|-----|-----------------|
# | 9 | 65.6 | 37 | 0 |
# | 9 | -4.0 | 46 | 0 |
# | 4 | 73.9 | 50 | 1 |
# | ... | ... | ... | ... |
#
# </center>
#
# Customer Status is 0 if the customer has stayed with the company and 1 if the customer has churned.

# %%
import numpy as np
import random as rnd
import pandas as pd
from matplotlib import pyplot as plt
from sklearn import linear_model, preprocessing
from sklearn.model_selection import train_test_split

np.random.seed(42)

def load_dataset(filename):
    data_train = pd.read_csv(filename)
    #permute the data
    data_train = data_train.sample(frac=1).reset_index(drop=True) # shuffle the data
    X = data_train.iloc[:, 0:3].values # Get first two columns as the input
    Y = data_train.iloc[:, 3].values # Get the third column as the label
    Y = 2*Y-1 # Make sure labels are -1 or 1 (0 --> -1, 1 --> 1)
    return X,Y

# Load the dataset
X, Y = load_dataset('data/telecom_customer_churn_cleaned.csv')

# %% [markdown]
# We are going to differentiate (classify) between **class "1" (churned)** and **class "-1" (stayed)**

# %% [markdown]
# ## Divide the data into training and test sets

# %%
# Compute the splits
m_training = int(0.75*X.shape[0]) # ---> percentage of training data

# m_test is the number of samples in the test set (total-training)
m_test =  X.shape[0] - m_training
X_training =  X[:m_training]
Y_training =  Y[:m_training]
X_test =   X[m_training:]
Y_test =  Y[m_training:] # ---> np array of -1s and +1s

print("Number of samples in the train set:", X_training.shape[0])
print("Number of samples in the test set:", X_test.shape[0])
print("Number of churned users in test:", np.sum(Y_test==-1))
print("Number of loyal users in test:", np.sum(Y_test==1))

# Standardize the input matrix
# ---> ie rescale tenure, charge and age st gaussian distribustion N(0,1) on the training set
# The transformation is computed on training data and then used on all the 3 sets
scaler = preprocessing.StandardScaler().fit(X_training) # ---> uses sklearn

np.set_printoptions(suppress=True) # sets to zero floating point numbers < min_float_eps ?
X_training =  scaler.transform(X_training)
print ("Mean of the training input data:", X_training.mean(axis=0))
print ("Std of the training input data:",X_training.std(axis=0))

X_test =  scaler.transform(X_test)
print ("Mean of the test input data:", X_test.mean(axis=0))
print ("Std of the test input data:", X_test.std(axis=0))
# Out:
# Number of samples in the train set: 2817
# Number of samples in the test set: 940
# Number of churned users in test: 465
# Number of loyal users in test: 475
# Mean of the training input data: [ 0. -0. -0.]
# Std of the training input data: [1. 1. 1.]
# Mean of the test input data: [ 0.0134851   0.04850383 -0.0433016 ]
# Std of the test input data: [1.00014294 1.00683022 1.02078989]

# %% [markdown]
# We will use **homogeneous coordinates** to describe all the coefficients of the model.
#
# _Hint:_ The conversion can be performed with the function $hstack$ in $numpy$.

# %%
print(X_training)
#print(X_test)
# Out:
# [[ 1.2361321   0.87798477 -0.16001986]
#  [ 0.10884685  0.4417593   1.37363294]
#  [ 1.69539647 -1.57223186 -0.04204657]
#  ...
#  [ 1.31963472 -1.58226003 -0.21900651]
#  [-0.09990967  0.91809746  0.01694008]
#  [-0.72617926 -0.18165871  0.25288666]]

# %%
def to_homogeneous(X_training, X_test):
    # TODO: Transform the input into homogeneous coordinates
    n_tr = X_training.shape[0]
    n_ts = X_test.shape[0]
    ones_tr = np.ones((n_tr,1)) # ---> rows by columns
    ones_ts = np.ones((n_ts,1))
    #print(ones_tr)
    #X_training_T = np.transpose(X_training)
    #print(X_training_T)
    #X_testing_T = np.transpose(X_training)
    Xh_training = np.hstack((ones_tr, X_training)) # ---> NB stacks columns
    Xh_test = np.hstack((ones_ts, X_test))
    return Xh_training, Xh_test

# %%
# convert to homogeneous coordinates using the function above
X_training, X_test = to_homogeneous(X_training, X_test)
print("Training set in homogeneous coordinates:")
print(X_training[:10])
# Out:
# Training set in homogeneous coordinates:
# [[ 1.          1.2361321   0.87798477 -0.16001986]
#  [ 1.          0.10884685  0.4417593   1.37363294]
#  [ 1.          1.69539647 -1.57223186 -0.04204657]
#  [ 1.          0.15059816 -0.93544295  0.84275312]
#  [ 1.          0.56811122 -0.38890759 -0.57292638]
#  [ 1.         -0.39216881 -1.41010975 -0.39596645]
#  [ 1.         -1.0184384  -1.53880462 -1.04481955]
#  [ 1.         -0.35041751 -0.71649454  0.72477983]
#  [ 1.         -1.18544362 -1.45857925  0.4298466 ]
#  [ 1.          1.44488863 -1.4385229  -0.16001986]]

# %% [markdown]
# ## Deterministic perceptron
#
# Now **complete** the function *perceptron*. <br>
# The **perceptron** algorithm **does not terminate** if the **data** is not **linearly separable**, therefore your implementation should **terminate** if it **reached the termination** condition seen in class **or** if a **maximum number of iterations** have already been run, where one **iteration** corresponds to **one update of the perceptron weights**. In case the **termination** is reached **because** the **maximum** number of **iterations** have been completed, the implementation should **return the best model** seen throughout.
#
# The current version of the perceptron is **deterministic**: we use a fixed rule to decide which sample should be considered (e.g., the one with the lowest index).
#
# The input parameters to pass are:
# - $X$: the matrix of input features, one row for each sample
# - $Y$: the vector of labels for the input features matrix X
# - $max\_num\_iterations$: the maximum number of iterations for running the perceptron
#
# The output values are:
# - $best\_w$: the vector with the coefficients of the best model (or the latest, if the termination condition is reached)
# - $best\_error$: the *fraction* of misclassified samples for the best model

# %%
#print(X_training[1], type(X_training[1]))

# %%
def count_errors(current_w, X, Y):
    # This function:
    # -computes the number of misclassified samples
    # -returns the indexes of all misclassified samples
    # -if there are no misclassified samples, returns -1 as index
    #acc = 0
    #index=[]
    #n_samples = X.shape[0]
    #n_errors =0
    #for i in range(n_samples):
    #    inner_product = np.sum(X[i] * current_w)
    #    #print(inner_product)
    #    if inner_product * Y[i] <= 0:
    #        acc = acc + 1
    #        index.append(i)
    #n = acc
    # Find all indices which have a different sign from the corresponding labels
    index = np.nonzero(np.sign(np.dot(X, current_w)) - Y)[0]
    # ---> NB for much faster speed (returns indexes of non-zero elements)
    n = np.array(index).shape[0]
    if (n == 0):
        # There are no misclassified samples
        return 0, -1
    return n, index

def perceptron_fixed_update(current_w, X, Y):
    # perceptron update function
    n_errors,index = count_errors(current_w, X, Y)
    if n_errors > 0: 
        first_error_index = index[0]
        new_w = current_w + Y[first_error_index] * X[first_error_index] # ---> for the first wrong i
    else:
        new_w = current_w
    return new_w

def perceptron_no_randomization(X, Y, max_num_iterations):
    # the perceptron main loop
    # The perceptron should run for up to max_num_iterations, or stop if it finds a solution with ERM=0
    n_samples = X.shape[0]
    n_features = X.shape[1]
    current_w = np.zeros(n_features) # ---> NB do NOT add extra dimension
    best_w = current_w.copy()
    best_error = 1.0
    
    for t in range(max_num_iterations):
        # ---> NB must keep the BEST model of all itertions, not simply the last one
        n_errors,index = count_errors(current_w, X, Y)
        current_error = n_errors / n_samples
        #print(index)
        if n_errors > 0:
            current_w = perceptron_fixed_update(current_w, X, Y)
            if current_error < best_error:
                best_w = current_w.copy()
                best_error = current_error
        else:
            best_w = current_w.copy() # ---> found solution
            break
        #print(n_errors)
    
    return best_w, best_error

# %% [markdown]
# Now we use the implementation above of the perceptron to learn a model from the training data using 30 iterations and print the error of the best model we have found.

# %%
w_found, error = perceptron_no_randomization(X_training,Y_training, 30)
print("Training Error of perceptron (30 iterations): " + str(error))
w_found2, error2 = perceptron_no_randomization(X_training,Y_training, 100)
print("Training Error of perceptron (100 iterations): " + str(error2))
# Out:
# Training Error of perceptron (30 iterations): 0.24565140220092296
# Training Error of perceptron (100 iterations): 0.24565140220092296

# %% [markdown]
# Now use the best model $w\_found$ to **predict the labels for the test dataset** and print the fraction of misclassified samples in the test set (the test error that is an estimate of the true loss).

# %%
def loss_estimate(w,X,Y):
    # Estimate the test loss
    n_errors, index = count_errors(w, X_test, Y_test)
    n_samples = X.shape[0]
    t_loss_estimate = n_errors / n_samples
    return t_loss_estimate


true_loss_estimate =  loss_estimate(w_found, X_test, Y_test)       # Error rate on the test set
true_loss_estimate2 =  loss_estimate(w_found2, X_test, Y_test) 
    
print("Test Error of perceptron (30 iterations): " + str(true_loss_estimate))
print("Test Error of perceptron (100 iterations): " + str(true_loss_estimate2))
# Out:
# Test Error of perceptron (30 iterations): 0.2904255319148936
# Test Error of perceptron (100 iterations): 0.2904255319148936

# %% [markdown]
# ### Randomized perceptron
#
# Implement the correct randomized version of the perceptron such that at each iteration the algorithm picks a random misclassified sample and updates the weights using that sample. The functions will be very similar, except for some minor details.

# %%
def perceptron_randomized_update(current_w, X, Y):
    # perceptron update function
    n_errors,index = count_errors(current_w, X, Y)
    if n_errors > 0: 
        random_error_index = np.random.choice(index)
        new_w = current_w + Y[random_error_index] * X[random_error_index] # ---> for the random wrong i
    return new_w

def perceptron_with_randomization(X, Y, max_num_iterations):
    # perceptron main loop
    # The perceptron should run for up to max_num_iterations, or stop if it finds a solution with ERM=0
    n_samples = X.shape[0]
    n_features = X.shape[1]
    current_w = np.zeros(n_features) # ---> NB do NOT add extra dimension
    best_w = current_w.copy()
    best_error = 1.0
    
    for t in range(max_num_iterations):
        # ---> NB must keep the BEST model of all itertions, not simply the last one
        n_errors,index = count_errors(current_w, X, Y)
        current_error = n_errors / n_samples
        #print(index)
        if n_errors > 0:
            current_w = perceptron_randomized_update(current_w, X, Y)
            if current_error < best_error:
                best_w = current_w.copy()
                best_error = current_error
        else:
            best_w = current_w.copy() # ---> found solution
            break
        #print(n_errors)
    return best_w, best_error

# %% [markdown]
# Now test the correct version of the perceptron using 30 iterations and print the error of the best model we have found.

# %%
# Now run the perceptron for 30 iterations
w_found, error = perceptron_with_randomization(X_training, Y_training, 30)
w_found2, error2 = perceptron_with_randomization(X_training, Y_training, 100)
print("Training Error of perceptron (30 iterations): " + str(error))
print("Training Error of perceptron (100 iterations): " + str(error2))

true_loss_estimate =  loss_estimate(w_found, X_test, Y_test)       # Error rate on the test set
true_loss_estimate2 =  loss_estimate(w_found2, X_test, Y_test) 

print("Test Error of perceptron (30 iterations): " + str(true_loss_estimate))
print("Test Error of perceptron (100 iterations): " + str(true_loss_estimate2))
# Out:
# Training Error of perceptron (30 iterations): 0.2552360667376642
# Training Error of perceptron (100 iterations): 0.24671636492722754
# Test Error of perceptron (30 iterations): 0.30531914893617024
# Test Error of perceptron (100 iterations): 0.3351063829787234

# %%
# Plot the loss with respect to the number of iterations (up to 1000)
num_iters = 1000 
num_iters_list = np.arange(1,num_iters, step=20)
erm_fixed_list = []
erm_random_list = []
for i in range(1,num_iters,20):
    print(i)
    _, erm_fixed = perceptron_no_randomization(X_training, Y_training, i)
    _, erm_random = perceptron_with_randomization(X_training, Y_training, i)
    erm_fixed_list.append(erm_fixed)
    erm_random_list.append(erm_random)
# Out:
# 1
# 21
# 41
# 61
# 81
# 101
# 121
# 141
# 161
# 181
# 201
# 221
# 241
# 261
# 281
# 301
# 321
# 341
# 361
# 381
# 401
# 421
# 441
# 461
# 481
# 501
# 521
# 541
# 561
# 581
# 601
# 621
# 641
# 661
# 681
# 701
# 721
# 741
# 761
# 781
# 801
# 821
# 841
# 861
# 881
# 901
# 921
# 941
# 961
# 981

# %%
plt.plot(num_iters_list, erm_fixed_list, label = "No randomization")
plt.plot(num_iters_list, erm_random_list, label = "With randomization")
plt.xlabel("Number of iterations")
plt.ylabel("Ratio of misclassified samples (on training set)") 
plt.legend()
plt.grid()
plt.show()
